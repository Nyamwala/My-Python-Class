# %% [markdown]
# ### Working with strings

# %%
cheapest_airline = "TAAG Angola Airline"

# %%
sentence = "I love Chipotles' lime and vinegar chicken bowl"
# we can also use escape characters to include quotes in a string

# %% [markdown]
# ### Multi-line strings

# %% [markdown]
# ### Methods

# %% [markdown]
# A method is a function that is only available to a specific data type

# %%
num = [4, 9, 99, 7, 0, 60]

# %%
num_tpl = tuple(num)

# %%
type(num_tpl)
# Out:
# tuple

# %%
num_tpl1 = tuple(num)

# %%
type(num_tpl1)
# Out:
# tuple

# %% [markdown]
# Reading assignment for Today
# - Replacing Parts of a string : " My Fave Colur is red" replace red with your actual fave colour
# - Changing the case of strings. "My name is Ladorna" - Change Lardona into fully Upper and Fully lower case
# - Strip
# - Split
# - Play around with 10 more sring methods from here : https://docs.python.org/3.12/library/stdtypes.html#string-methods

# %%
month = "August"
month = month.lower()
print(month)
# Out:
# august

# %%
user_name = " Roberto "
user_name = user_name.strip()
print(user_name)
# Out:
# Roberto

# %% [markdown]
# **Lambda Functions**

# %% [markdown]
# - Are  quick and easy way to write functions with the keyword lambda

# %%
# A function that take two parameters a and b and raises a to the power of b

def raisea2b (a, b):
    """A function that takes two parameters a and b and raises a to the poer of b"""
    raised_to_b = a ** b
    print(raised_to_b)

raisea2b(20, 3)
# Out:
# 8000

# %%
raisex2y_short = lambda x, y: x ** y
print(raisex2y_short(20, 3))
# Out:
# 8000

# %% [markdown]
# **Anonymous Functions**

# %%
nums = [10, 30, 60, 15]

squared_nums = map(lambda num: num ** 2, nums)

print(squared_nums)
# Out:
# <map object at 0x0000011C081C5C30>

# %%
print(list(squared_nums))
# Out:
# [100, 900, 3600, 225]

# %% [markdown]
# ### Regular explations

# %% [markdown]
# ### String manipulation
# - Replacing and finding specific sub strings

# %% [markdown]
# #### string formatting
# - Interpolating a string into a template

# %% [markdown]
# **why is regular expression important**
# - Clean our datasets and preparing them for **Natural language processing (NLP)*** Tasks like setiment ananlysis,
# text mining e.t.c
# - Process email contents to feed to a ML algorithm that check whether the email is a spam or not
# - parse and extract text specific data from a website that you can use to build a DB(web scaping)

# %%
Mystring = "Amazing learning experience so far"
Mystring2 = "here at Zindua school"

# %%
# Finding the length of a string
len(Mystring)
# Out:
# 34

# %%
complete_sentence = Mystring + " " + Mystring2
complete_sentence
# Out:
# 'Amazing learning experience so far here at Zindua school'

# %% [markdown]
# **string operations**
# - This includes the .lower(), .upper() , .capitalize()

# %%
# splitting a string into a list of substrings 
complete_sentence.split(sep=" ", maxsplit = 2)
# Out:
# ['Amazing', 'learning', 'experience so far here at Zindua school']

# %%
# splitting a string into a list of substrings using an escape error character
my_new_sentence = "My favorite artists are \n1. Coster Ojwang\n2.  Bien\n3. Scar Mkadinali"
print(my_new_sentence)
# Out:
# My favorite artists are
# 1. Coster Ojwang
# 2.  Bien
# 3. Scar Mkadinali

# %%
# using the split method
my_new_sentence.split(sep="\n", maxsplit = 3)
# Out:
# ['My favorite artists are ',
#  '1. Coster Ojwang',
#  '2.  Bien',
#  '3. Scar Mkadinali']

# %%
my_new_sentence.splitlines()
# Out:
# ['My favorite artists are ',
#  '1. Coster Ojwang',
#  '2.  Bien',
#  '3. Scar Mkadinali']

# %%
# '.join(iterable)'

# %% [markdown]
# **Finding and replacing strings**
#  - 'string.find(substracting, start, end(Exclusive just line in indexing))'

# %%
my_name = "My name is Brayan not Brian"

# %%
# Finding a substring in a string
my_name.find("Brayan", 0, 30) # 0, 30 represents index
# Out:
# 11

# %%
name_str = " The speaker's name is Robert"

# %%
name_str.replace("Robert", "Roberto")
# Out:
# " The speaker's name is Roberto"

# %% [markdown]
# ### Regular expressions

# %% [markdown]
# -  A regular character is a string containing a combination of 'normal caracter' and 'special characters' that the **patterns** to find text or positions within a text

# %%
import re

# %%
movie_str = "I really enjoyed watching te movie '#1Spid7er-man: Brand new Day' and I would recommend it "

# %%
# use regular expression to only find the movie in the string 'movie_str' above

"""
The syntax of find all is :
're.findall(r'regex_pattern', string_to_search)'
"""

re.findall(r"#1Spid\d", movie_str)


# movie_name = re.search(r"Movie #[0-9] +([A-zA-Z0- ]+)", movie_str)
# if movie_name:
# print(movie_name.group(1))
# Out:
# ['#1Spid7']

# %% [markdown]
# | Metacharater| Meaning     |Code Example| What the Code Does|
# |------|------|------|------|
# |   \d   | Digit     |  `re.findall(r'User\d', "The Winners for the Hackathon are User6 and User8")`|Finds all characters with the word User followed by a digit|
# |   \D  | Non-Digit     |  `re.findall(r'User\D', "The Winners for the Hackathon are UserK, UserL and User8")`|Finds all characters with the word User followed by a non-digit|
# |   \w  | word  |  `re.findall(r'User\w', "The Winners for the Hackathon are User9, UserJ and UserPQ")`|Finds all characters with the word User followed by any digit or normal character|
# |   \W  | Non-word  |  re.findall(r'\W\d\d', "The Concert tickets for Fally Ipupa's concert were $47")`|Finds a price inside our string. We use `\W to match the dollar sign followed by two digits|
# |   \s  | Whitespace  |  `re.findall(r'Zindua\sSchool', "I am having a great time learning at Zindua School")`|Specifies a Whitespace|
# |   \S  | Non-Whitespace  |  re.sub(r'Mashujaa\SDay','Mashujaa Day' , "In the month of October we celebrate Mashujaa-Day In Kenya")`|Detects matches of `Mashujaa folowed by any non-space character followed by Day and replace them with the word `Mashujaa Day`|

# %% [markdown]
# **Sample \d Metacharacter**

# %%
winners = "The winners for the Hackathon are User6 and User8"
re.findall(r'User\d', winners)
# Out:
# ['User6', 'User8']

# %% [markdown]
# **Sample \D Metacharacter**

# %%
winners2 = "The winners for the Hackathon are userK, userL and User8"
re.findall(r'user\D', winners2)
# Out:
# ['userK', 'userL']

# %% [markdown]
# **Sample \w Metacharacter**

# %%
winners3 = "The winners for the Hackathon are user9, userJ and userPQ"

re.findall(r'user\w', winners3)
# Out:
# ['user9', 'userJ', 'userP']

# %% [markdown]
# **Sample W\ metacharacter**

# %%
re.findall(r'\W\d\d', "The concert tickets for Fally Ipupa's concert were $47")
# Out:
# ['$47']

# %% [markdown]
# **Sample \s**

# %%
re.findall(r'Zindua\sSchool', "I am having a great time learning at Zindua School")
# Out:
# ['Zindua School']

# %% [markdown]
# **sample \S Metacharacter**

# %%
re.sub(r'Mashujaa\SDay','Mashujaa Day', "In the month of October we celebrate Mashujaa Day in Kenya")
# Out:
# 'In the month of October we celebrate Mashujaa Day in Kenya'

# %% [markdown]
# #### Web Scraping

# %%
import webbrowser
import requests
import threading
from bs4 import BeautifulSoup

# %%
def scrape_news():
    url = 'https://edition.cnn.com/world'
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # CNN uses different tags for headlines
        headlines = soup.find_all('span', class_='container__headline-text')  # Adjust according to CNN's structure

        # Print the number of headlines found for debugging
        print(f"Found {len(headlines)} headlines.")
        
        news_list = [headline.get_text().strip() for headline in headlines[:5]]  # Get the top 5 headlines
        if news_list:
            return "\n".join(news_list)
        else:
            return "No headlines found."
    else:
        return "Failed to retrieve news."
scrape_news()
# Out:
# Found 93 headlines.
# 'Ex-CIA boss was at Ukrainian station when Russian drone struck train\nTrump tells Zelensky to stop targeting Russian refiners as diesel soars amid Iran war\nIran reports commercial vessel struck in Strait of Hormuz\nSweden’s parliamentary election heads to a close finish\nAt least 6 dead and more than 100 missing after Indonesian ferry overturns in rough seas'
