# %% [markdown]
# # Introduction to Python

# %%
print("Where is the place called Bomblast in Nairobi ")
# Out:
# Where is the place called Bomblast in Nairobi

# %% [markdown]
# ## Variables in Python

# %%
# This is an integer variable
total_price = 10 + 20
total_price
# Out:
# 30

# %%
type(total_price)
# Out:
# int

# %%
# This is a string variable
fave_fruit = "Apple"

# %%
type(fave_fruit)
# Out:
# str

# %%
TravelledByShip = "False"

# %%
type(TravelledByShip)
# Out:
# bool

# %%
totalDiscount = 12.7

# %%
type(totalDiscount)
# Out:
# float

# %%
# This is also a string variable
sentence = "My sisters name is Annette"
sentence
# Out:
# 'My sisters name is Annette'

# %% [markdown]
# # Naming conventions for variables in python
#
# **Snake Case**
#
# total_spend = 20
#
# **Camel Case**
#
# TotalSpend = 20
#
# **Pascal Case**
#
# totalSpend = 20
#
# _which one is your favorite_
#
# >All of these are accepted its just more of a personal preference

# %% [markdown]
# ### Calcultion with Variables

# %%
original_price = 7000
price_after_discount = 6760

# What is the discount percentage?
discount_percentage = ((original_price - price_after_discount) / original_price) * 100
discount_percentage
# Out:
# 3.428571428571429

# %%
discount = (discount_percentage * original_price) / 100
discount
# Out:
# 240.0

# %% [markdown]
# ## Conditional statements and operators

# %%
# Boolean variable

found_guilty = False
type = (found_guilty)

# used to make comparisons and make decisions in code. It can only be True or False.

# %% [markdown]
# ## Operators
#
# 1. Arithmetic operators
# +, -, *, %
#
# 2. Comparison operators
# <, !=, =
# 3. Checking for equality

# %%
## Checking for equality

32 == 23
# Out:
# False

# %%
32 != 23
# Out:
# True

# %% [markdown]
# Numeric Comparison Operators

# %%
# Is 5 less than 10
5 < 10
# Out:
# True

# %%
5 >= 30
# Out:
# False

# %% [markdown]
# Other comparisons

# %%
# Is Roberto greater than Moses
"Roberto" > "Moses"
# Out:
# True

# %%
# Is Yasmin greater than Denis
"Denis" > "Yasmin"
# Out:
# False

# %%
# Is Denis ggreater than Daniel
"Denis" > "Daniel"
# Out:
# True

# %% [markdown]
# ### Conditional statements
# - if "True" perfom a task
# - Otherwise do nothing

# %%
# Target grade and attained grade
attained_grade = 60
target_grade = 50

# Comparing of the grade

if attained_grade >= target_grade:
    print("Target grade achieved")
# Out:
# Target grade achieved

# %% [markdown]
# > Always remember to indent the right way
# Here are the guidlines by PEP 8 on indentation: https://peps.python.org/pep-008#/indentation

# %%
# Grade attained and Target grade
attained_grade = 30
target_grade = 50

# Comparing of the grade

if attained_grade >= target_grade:
    print("Target grade achieved")
# Check if they havent hit the target grade
elif attained_grade < target_grade:
    print("Target grade not achieved")

# Check if the grade is equal to zero
elif attained_grade == 0:
    print("You have a grade of zero, please contact your lecturer for assistance")
# if anything else apart from a number is passed, throw an errror
else:
    print("Invalid grade entered, please contact your lecturer")
# Out:
# Target grade not achieved

# %%
# target sales and actual sales
target_sales = 1000
actual_sales = 3000

# Compare our sales 
if actual_sales >= target_sales:
    print("Target sales achieved")

# Check if we are close to hitting target sales 
if actual_sales >= 920:
    print("Target sales almost achieved")
else:
    print("Target sales not achieved")
# Out:
# Target sales achieved
# Target sales almost achieved

# %% [markdown]
# > you can have as many elif keywords as you can, but only 1 if and 1 else keyword

# %% [markdown]
# |Keyword |Function |Use |
# |-|-|-|
# | "if" | Check if a condition is met | First in the workflow |
# | "elif" | Check if another condition is met | After "if" |
# | "else" | else perfom this action | after "alif" or "if"|

# %% [markdown]
# Loops

# %% [markdown]
# - We have the following loops in python
#     - For loops
#     - While loops
# - We also have different data structures and these include
#     - Lists
#     - Dictionaries
#     - Tuples
#     - Sets

# %% [markdown]
# Lists

# %% [markdown]
# - Lists store multiple variables in a single variable
#     - Can contain any combination of data types
#     - We define lists using square brackets []

# %%
rand_lists = ["Anita" , 20, True, 90.45, 360]
type(rand_lists)
# Out:
# list

# %%
grade = [10, 20, 30, 40, 50]

# %% [markdown]
# ### Accessing elements in lists

# %%
grade = [10, 20, 30, 40, 50]
grade[1:4]
# Out:
# [20, 30, 40]

# %% [markdown]
# ### Accessing multiple elements in lists

# %%
grade = [10, 20, 11, 30, 40]
grade[1:3]
# Out:
# [20, 11]

# %%
grade = [10,20,11,30,40]
grade[0:4]
# Out:
# [10, 20, 11, 30]

# %%
price = [10, 20, 11, 30, 40]
result = [price[i] for i in [0, 2, 4]]
print(result)
# Out:
# [10, 11, 40]

# %%
price[0:5:2]
# Out:
# [10, 11, 40]

# %%
ingredients = ["sugar", "coconut milk", "fresh palm wine", "cadarmon", "wheat flour", "yeast", "coocking oil"]

# %%
# Getting the first four ingredients
first_four = ingredients[:4]
print(first_four)
# Out:
# ['sugar', 'coconut milk', 'fresh palm wine', 'cadarmon']

# %%
# Accessing every second ingredient in the list
ingredients[::2]
# Out:
# ['sugar', 'fresh palm wine', 'wheat flour', 'coocking oil']

# %%
# Access every third ingredient starting from the second ingredient
ingredients[1::3]
# Out:
# ['coconut milk', 'wheat flour']

# %% [markdown]
# ### Dictionaries
# - It is pythons most powerful built in data type
# - it allows you to store data as key value pairs

# %% [markdown]
# ## Comparison to lists
# - in a list you access elements using an index, which must be an integer
# - in a dictionary the indices can be (almost) any type. we call these indices keys
# - Each key maps to a specific value
#
# Terminology
# - Key; The label or index (a word or user ID)
# - Value; The data associated with the key (a definition or a score)
# - Item; The combination of a key and its value

# %% [markdown]
# ### Creating and populating dictionaries
#
# > you can create dictionaries using the dict() constructor or curly braces {}

# %% [markdown]
# ### English to spanish mapping

# %%
# 1. Creating an empty dictionary
eng2sp = dict()
print(eng2sp)
# output: {} <--- curly braces represent a dictionary

# 2. Addding items (key value pairs)
# syntax dictionary_name[key] = value
eng2sp["one"] = "uno"
eng2sp["two"] = "dos"

print(eng2sp)
# output: {'one': 'uno', 'two': 'dos'}
# Out:
# {}
# {'one': 'uno', 'two': 'dos'}

# %% [markdown]
# ### Initialization syntax
# - you can also create a dictionary with data already inside it
# - The output shown above is exactly the same as the input format

# %%
eng2sp = {'one': 'uno', 'two': 'dos', 'three': 'tres'}

# %% [markdown]
# ### Essential properties and operations
# - Dictionaries preserve insertion order. If you add "one" then "two" they will stay in that order

# %% [markdown]
# - length (len)
# - The len function counts the number of key value pairs

# %%
print(len(eng2sp))
# output: 3
# Out:
# 3

# %% [markdown]
# - The in operator (Membership)

# %% [markdown]
# - The in operator checks if something exists as a key not as a value

# %%
# Checking keys
print("one" in eng2sp) # True
print("uno" in eng2sp) # False (because "uno" is a value, not a key)
# Out:
# True
# False

# %% [markdown]
# > To check if something exists as a value you must use the .value() method

# %%
vals = list(eng2sp.values()) # converts values into a list ['uno', 'dos', 'tres']
print('uno' in vals) # True
# Out:
# True

# %% [markdown]
# ### Dictionaries patterns
# - covers standard programming "idioms" of writing code that Python programmers use frequently to solve specific problems.

# %% [markdown]
# ### The Histogram pattern (counters)
# - A "Histogram" is a statistical term for a set of counters.
# - The most common application is counting the frequency of letters in a word or words in a text.

# %% [markdown]
# ### Method A: The explicit logic (using if/else)
# - we iterate through a string for each character
# 1. check if we have seen it before (is it in the dictionary)
# 2. if No: Create a new entry with count 1
# 3. if yes: Update the existing entry by adding 1

# %%
word = "brontosaurus"
d = dict()
for c in word:
    if c not in d:
        d[c] = 1 # first time seeing this letter
else:
    d[c] = d[c] + 1 # seen it before, increment the count by 1
    print(d)
    # output: {'b': 1, 'r': 2, 'o': 2, 'n': 1, 't': 1, 's': 2, 'a': 1, 'u': 2}
# Out:
# {'b': 1, 'r': 1, 'o': 1, 'n': 1, 't': 1, 's': 2, 'a': 1, 'u': 1}

# %% [markdown]
# **why do we use dictionaries**
# - 'username'
# - 'email'
# - 'preferences'
# - 'ip address'
# - 'location'

# %%
ingredients = ["sugar", "coconut milk", "fresh palm wine", "cadarmon", "wheat flour", "yeast", "coocking oil"]
quantity = [200, 50, 60, 500, 4, 170, 70]

# %%
recipe = {"coconut milk": 200,
          "Cardamon": 50,
          "fresh palm wine": 60,
          "sugar": 500,
          "wheat flour": 4,
          "yeast": 170,
          "cooking oil": 70}
print(recipe)
type(recipe)
# Out:
# {'coconut milk': 200, 'Cardamon': 50, 'fresh palm wine': 60, 'sugar': 500, 'wheat flour': 4, 'yeast': 170, 'cooking oil': 70}
# dict

# %% [markdown]
# ### Accessing value based on a key
# - Dictionaries are ordered
#     - This allows values to be accessed by _subsetting on the key

# %%
# How many grams of fresh palm wine do we need for our mahamri?
print(recipe["fresh palm wine"])
# Out:
# 60

# %% [markdown]
# ### Accessing all the values in your dictionary

# %%
print(recipe.values())
# Out:
# dict_values([200, 50, 60, 500, 4, 170, 70])

# %% [markdown]
# **accessing all the keys**

# %%
print(recipe.keys())
# Out:
# dict_keys(['coconut milk', 'Cardamon', 'fresh palm wine', 'sugar', 'wheat flour', 'yeast', 'cooking oil'])

# %% [markdown]
# **Accessing your entire dictionary**

# %%
print(recipe)
# Out:
# {'coconut milk': 200, 'Cardamon': 50, 'fresh palm wine': 60, 'sugar': 500, 'wheat flour': 4, 'yeast': 170, 'cooking oil': 70}

# %%
print(recipe.items())
# Out:
# dict_items([('coconut milk', 200), ('Cardamon', 50), ('fresh palm wine', 60), ('sugar', 500), ('wheat flour', 4), ('yeast', 170), ('cooking oil', 70)])

# %% [markdown]
# ### Adding a key value pair to our dictionary

# %%
print(recipe)
# Out:
# {'coconut milk': 200, 'Cardamon': 50, 'fresh palm wine': 60, 'sugar': 500, 'wheat flour': 4, 'yeast': 170, 'cooking oil': 70}

# %%
recipe["salt"] = 5

# %%
print(recipe)
# Out:
# {'coconut milk': 200, 'Cardamon': 50, 'fresh palm wine': 60, 'sugar': 500, 'wheat flour': 4, 'yeast': 170, 'cooking oil': 70, 'salt': 5}

# %% [markdown]
# #### Update a value

# %%
print(recipe)
# Out:
# {'coconut milk': 200, 'Cardamon': 50, 'fresh palm wine': 60, 'sugar': 500, 'wheat flour': 4, 'yeast': 170, 'cooking oil': 70, 'salt': 5}

# %%
# Updating a value based on existing key
recipe["wheat flour"] = 10

# %%
print(recipe)
# Out:
# {'coconut milk': 200, 'Cardamon': 50, 'fresh palm wine': 60, 'sugar': 500, 'wheat flour': 10, 'yeast': 170, 'cooking oil': 70, 'salt': 5}

# %% [markdown]
# **Duplicate keys**

# %%
eoy_results = {"Dennis": 70,
                "kai": 80,
                "Daniel": 80, 
                "Daniel": 65,
                 "Yasmin": 50}

# %%
print(eoy_results["Daniel"])
# Out:
# 65

# %%
print(eoy_results)
# Out:
# {'Dennis': 70, 'kai': 80, 'Daniel': 65, 'Yasmin': 50}

# %% [markdown]
# ### Sets

# %% [markdown]
# - Sets contain unique data
# - They are unchangable
#     - you can add or remove values but you cannot change them
# - Ideal to identify and remove duplicates
# - Its quick to search as compared to other data structures such as lists

# %% [markdown]
# **Creating a set**

# %% [markdown]
# - set = {}
# - sets do not include ':' = Dictionaries
# - No ':' = Set

# %%
mahamri_ingredients = {"sugar": 1, "coconut milk": 1, "fresh palm wine" :1, "cadarmon": 1, "wheat flour" :1, "yeast" :1, "cooking oil" :1}

# %%
print(mahamri_ingredients)
type(mahamri_ingredients)
# Out:
# {'sugar': 1, 'coconut milk': 1, 'fresh palm wine': 1, 'cadarmon': 1, 'wheat flour': 1, 'yeast': 1, 'cooking oil': 1}
# dict

# %% [markdown]
# **converting to a set**

# %%
duplicate_ingredients = [ "coconut milk",  "cadarmon", "sugar", "wheat flour", "yeast",
                          "fresh palm wine", "cooking oil", "cooking oil", "cardamon", "sugar"]

# %%
print(duplicate_ingredients)
type(duplicate_ingredients)
# Out:
# ['coconut milk', 'cadarmon', 'sugar', 'wheat flour', 'yeast', 'fresh palm wine', 'cooking oil', 'cooking oil', 'cardamon', 'sugar']
# list

# %%
unique_ingredients = set(duplicate_ingredients)

# %%
print(unique_ingredients)
type(unique_ingredients)
# Out:
# {'wheat flour', 'cardamon', 'coconut milk', 'sugar', 'fresh palm wine', 'cooking oil', 'yeast', 'cadarmon'}
# set

# %% [markdown]
# **Limitations of sets**
# - sets do not have an index meaning they are not ordered
#     - cant subset sets [] /slice them
#     - we cannot then have duplicates

# %%
print(unique_ingredients)
# Out:
# {'wheat flour', 'cardamon', 'coconut milk', 'sugar', 'fresh palm wine', 'cooking oil', 'yeast', 'cadarmon'}

# %% [markdown]
# #### Tuples

# %% [markdown]
# - Tuples are **immutable**, meaning they cannot be changed
#     - no adding values
#     - no removing values
#     - no changing values
#
# - tuples are ordered
#     - we can sub-set tuples by index [0]
#
# - Tuples are useful in
#     - location data
#     - identifiers

# %% [markdown]
# **creating a tuple**

# %%
kra_pin = ("AO8YSDHDN ", "A7UYTGDFGHDD", "A3YJDDDBFFH", "ASDEUYT6563", "CSW367YEEEEH", "AHSSDHEUE83737")

# %%
print(kra_pin)
type(kra_pin)
# Out:
# ('AO8YSDHDN ', 'A7UYTGDFGHDD', 'A3YJDDDBFFH', 'ASDEUYT6563', 'CSW367YEEEEH', 'AHSSDHEUE83737')
# tuple

# %%
# creating a tuple from a list
kra_pin = ("AO8YSDHDN ", "A7UYTGDFGHDD", "A3YJDDDBFFH", "ASDEUYT6563", "CSW367YEEEEH", "AHSSDHEUE83737")

# %%
print(kra_pin)
type(kra_pin)
# Out:
# ('AO8YSDHDN ', 'A7UYTGDFGHDD', 'A3YJDDDBFFH', 'ASDEUYT6563', 'CSW367YEEEEH', 'AHSSDHEUE83737')
# tuple

# %% [markdown]
# **Accessing tuples**

# %%
print(kra_pin)
# Out:
# ('AO8YSDHDN ', 'A7UYTGDFGHDD', 'A3YJDDDBFFH', 'ASDEUYT6563', 'CSW367YEEEEH', 'AHSSDHEUE83737')

# %%
print(kra_pin[2])
# Out:
# A3YJDDDBFFH

# %%
kra_pin = ("AO8YSDHDN ", "A7UYTGDFGHDD", "A3YJDDDBFFH", "ASDEUYT6563", "CSW367YEEEEH", "AHSSDHEUE83737")

# %%
unchangable_kra_pins = tuple(kra_pin)

# %%
print(unchangable_kra_pins)
type(unchangable_kra_pins)
# Out:
# ('AO8YSDHDN ', 'A7UYTGDFGHDD', 'A3YJDDDBFFH', 'ASDEUYT6563', 'CSW367YEEEEH', 'AHSSDHEUE83737')
# tuple

# %%
print(kra_pin[3])
# Out:
# ASDEUYT6563

# %%
print(kra_pin[1])
# Out:
# A7UYTGDFGHDD

# %% [markdown]
# ### Loops

# %% [markdown]
# - we have the following type of loops in python
#     - for loops
#     - while loops

# %% [markdown]
# **for loops**

# %%
student_grades = [10, 13, 65, 59, 21, 45, 90, 33, 0, 88 ]

# %%
print(student_grades)
# Out:
# [10, 13, 65, 59, 21, 45, 90, 33, 0, 88]

# %%
# printing the grade of each student in the list
for grade in student_grades:
    print(grade)
# Out:
# 10
# 13
# 65
# 59
# 21
# 45
# 90
# 33
# 0
# 88

# %% [markdown]
# **conditional statements in for loops**

# %%
# print out only grades that are greater than or equal to 50

for grade in student_grades:
    # check if the grade is greater than or equal to 50
    if grade >= 50:
        print(grade)
# Out:
# 65
# 59
# 90
# 88

# %%
# check how many students have scored 50 and above

graduating_students = 0
students_not_graduating = 0
for grade in student_grades:
    # check if the grade is greater than or equal to 50
    if grade >= 50:
        graduating_students += 1
    else:
        students_not_graduating +=1

print(f"number of students who are graduating {graduating_students}")
print(f"number of student not graduating:{students_not_graduating}")
print(f"Total number of students: {graduating_students + students_not_graduating}")
# Out:
# number of students who are graduating 4
# number of student not graduating:6
# Total number of students: 10

# %% [markdown]
# ### while loops

# %% [markdown]
# - 'break' and 'continue' statement

# %% [markdown]
# - while loops are very useful for continuous tasks :
#     - Accelerate 'while' a button is being pressed
#     - monitor 'while' below or above threshhold

# %%
# items in stock
stock = 10

# Number of purchases 
purchases = 0

while purchases < stock:
    # when a customer buys something increase purchases by 1
    purchases += 1
    # print for me remaining stock from each purchase
    print(f"remaining stock: {stock - purchases}")
# Out:
# remaining stock: 9
# remaining stock: 8
# remaining stock: 7
# remaining stock: 6
# remaining stock: 5
# remaining stock: 4
# remaining stock: 3
# remaining stock: 2
# remaining stock: 1
# remaining stock: 0

# %% [markdown]
# **sample use case of break and continue**

# %%
# items in stock
stock = 10

# Number of purchases 
purchases = 0

while purchases < stock:
    # when a customer buys something increase purchases by 1
    # purchases += 1
    # print for me remaining stock from each purchase
    print(f"remaining stock: {stock - purchases}")

    # Terminate the loop
    break
# Out:
# remaining stock: 10

# %% [markdown]
# **Keywords in Python**
# - and: check if multiple conditions are met
# - or: check if one or more condition is met
# - in: used to check if a value is in a variable or a a data structure
# - not: check if a condition is not met
# - is in:
# - is not

# %%
# The 'in' keyword
Flight_numbers = {"KQ100": "LHR", "KQ113": "NBO",
                   "KQ414": "EBB", "KQ508":"ACC",
                   "KQ760": "JNB", "KQ886": "BKK"}

# %%
# Check if there is a key for a flight to CPT KQ792
if "KQ792" in Flight_numbers:
    print("Kenya airways has a flight to CPT with flight number KQ792.")

else:
    #Add that flight to the dictionary and then print it
    Flight_numbers ["KQ792"] = "CPT"
    print(f"added KQ792 to Flight_numbers: {Flight_numbers}")
# Out:
# added KQ792 to Flight_numbers: {'KQ100': 'LHR', 'KQ113': 'NBO', 'KQ414': 'EBB', 'KQ508': 'ACC', 'KQ760': 'JNB', 'KQ886': 'BKK', 'KQ792': 'CPT'}

# %%
# Check if there is a key for a flight to CPT KQ792
if "KQ792" and "KQ2" in Flight_numbers:
    print("Kenya airways has a flight to CPT and New York")

else:
    #Add that flight to the dictionary and then print it
    Flight_numbers["KQ2"] = "JFK"
    
    # Print the value whose key is KQ2
    print(Flight_numbers["KQ2"])
# Out:
# JFK

# %%
Flight_numbers
# Out:
# {'KQ100': 'LHR',
#  'KQ113': 'NBO',
#  'KQ414': 'EBB',
#  'KQ508': 'ACC',
#  'KQ760': 'JNB',
#  'KQ886': 'BKK'}

# %% [markdown]
# ### Functions in Python

# %% [markdown]
# - In programming we have the DRY principle : Do not repeat yourself

# %% [markdown]
# ### Built-in Functions

# %%
x = 30
y = str(x)
type(x)
# Out:
# int

# %%
y = str(x)
print(y)
type(y)
# Out:
# 30
# str

# %%
y_int = int(y)
print(y_int)
type(y_int)
# Out:
# 30
# int

# %%
# A function to calculate my rough shopping costs
def shopping_estimate():               #Function Definition/Header
    """This function adds to the costs of items in my shopping list and returns the Total estimated cost."""

    total_estimate = 500 + 600        # Function Body
    print(total_estimate)             # Function Body
    
shopping_estimate()                   # Function Call
# Out:
# 1100

# %% [markdown]
# **Function Parameters/Arguments**

# %%
def happiness_purchase_estimate(Ahmed_mango, Daniel_fords, Yasmin_gold,
                                 Gloria_vacay, Charmaine_gun, Roberto_friedchicken, Moses_Ps5):
    """This function adds the costs of items in my happiness purchase list   # Function Documentation/ Docstrings"""

    total_price_estimate = Ahmed_mango + Daniel_fords + Yasmin_gold + Gloria_vacay + Charmaine_gun + Roberto_friedchicken + Moses_Ps5
    print(total_price_estimate)

happiness_purchase_estimate(100, 13000000,975000, 150000 , 100000, 2000, 80000 )
# Out:
# 14307100

# %%
# passing an unlimited number of arguments to a function using *args
def happiness_purchase_unlimited(*happinessPrice):
    """This function adds the cost of items in my hapiness purchase list"""

    total_price_estimate = sum(happinessPrice)

    print(total_price_estimate)

happiness_purchase_unlimited(100, 13000000,975000, 150000 , 100000, 2000,
                              80000, 9500000, 22000000, 12947.30, 40000000, 29000)
# Out:
# 85849047.3

# %%
count = 0
def happiness_purchase_with_kwargs(**happinessPrice):
    """This function adds the costs of items in my happiness purchase list"""

    total_price_estimate = sum(happinessPrice.values())
    print(type(total_price_estimate))

    for key in happinessPrice.keys():
        global count
        count += 1
    total_students = count

    print(total_students)
    print(total_price_estimate)

happiness_purchase_with_kwargs(Ahmed_mango=100, Daniel_fords=13000000, Yasmin_gold=975000, Gloria_vacay=150000,
                                   Charmaine_gun=100000, Roberto_friedchicken=2000, James_tx=9500000, kai_defender=22000000,
                                   Norman_apartment=40000000, Erick_stocks=29000, dennis_jersey=12947.30, 
                                   christina_rangerover=7000000)
# Out:
# <class 'float'>
# 12
# 92769047.3

# %%
def raise_value(a, b):
    """ Raise the values a and b to power 2 and 3 respectively and return the results"""

    raised_to_two = a ** 2
    raised_to_three = b ** 3

    answer = (raised_to_two, raised_to_three)

    print(type(answer))

    return(answer)

raise_value(12,70)
# Out:
# <class 'tuple'>
# (144, 343000)

# %%
API_KEY = "78bec5d35f018fbe84e0ff829c76b906"

# %%
# Importing the requests library to make API calls
import requests

# %%
def get_weather(city):
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        main = data['main']
        temperature = main['temp']
        weather_description = data['weather'][0]['description']
        return f"The temperature in {city} is {temperature} degrees celcius with {weather_description}."
    else:
        return "I couldn't retreive the weather information"

# %%
get_weather("Kilifi")
# Out:
# 'The temperature in Kilifi is 28.29 degrees celcius with few clouds.'

# %%
get_weather("Homa Bay")
# Out:
# 'The temperature in Homa Bay is 26.94 degrees celcius with few clouds.'

# %%
get_weather("Westlands")
# Out:
# 'The temperature in Westlands is 12.88 degrees celcius with overcast clouds.'

# %%
get_weather("Kisumu")
# Out:
# 'The temperature in Kisumu is 27.89 degrees celcius with scattered clouds.'

# %%
get_weather("Bungoma")
# Out:
# 'The temperature in Bungoma is 29.14 degrees celcius with few clouds.'

# %%
get_weather("Nyeri")
# Out:
# 'The temperature in Nyeri is 21.73 degrees celcius with scattered clouds.'

# %%
get_weather("Nanyuki")
# Out:
# 'The temperature in Nanyuki is 23.96 degrees celcius with few clouds.'

# %%
# This JSON represents the results returned from an image search.

{
  "total": 4692, # total number of images matching the search.
  "totalHits": 500, # the number of matching results the API can return.
  "hits": [           # an array (list) of individual image records.
    {
      "id": 195893,   # unique image identifier
      "pageURL": "https://pixabay.com/en/blossom-bloom-flower-195893/",    # Pixabay page for the image.
      "type": "photo",    # asset type, such as "photo".
      "tags": "blossom, bloom, flower",  # keywords describing the image
      "previewURL": "https://cdn.pixabay.com/photo/2013/10/15/09/12/flower-195893_150.jpg", # links to differently sized versions of the image
      "previewWidth": 150, # size of the preview image in pixels
      "previewHeight": 84,  
      "webformatURL": "https://pixabay.com/get/35bbf209e13e39d2_640.jpg",
      "webformatWidth": 640,
      "webformatHeight": 360,
      "largeImageURL": "https://pixabay.com/get/ed6a99fd0a76647_1280.jpg",
      "fullHDURL": "https://pixabay.com/get/ed6a9369fd0a76647_1920.jpg",
      "imageURL": "https://pixabay.com/get/ed6a9364a9fd0a76647.jpg",
      "imageWidth": 4000,
      "imageHeight": 2250,
      "imageSize": 4731420,
      "views": 7671, # image popularity statistics 
      "downloads": 6439,
      "likes": 5,
      "comments": 2,
      "user_id": 48777, # the uploader’s identifier and username
      "user": "Josch13",
      "userImageURL": "https://cdn.pixabay.com/user/2013/11/05/02-10-23-764_250x250.jpg" # the uploader’s profile image
    }
  ]
}
# Out:
# {'total': 4692,
#  'totalHits': 500,
#  'hits': [{'id': 195893,
#    'pageURL': 'https://pixabay.com/en/blossom-bloom-flower-195893/',
#    'type': 'photo',
#    'tags': 'blossom, bloom, flower',
#    'previewURL': 'https://cdn.pixabay.com/photo/2013/10/15/09/12/flower-195893_150.jpg',
#    'previewWidth': 150,
#    'previewHeight': 84,
#    'webformatURL': 'https://pixabay.com/get/35bbf209e13e39d2_640.jpg',
#    'webformatWidth': 640,
#    'webformatHeight': 360,
#    'largeImageURL': 'https://pixabay.com/get/ed6a99fd0a76647_1280.jpg',
#    'fullHDURL': 'https://pixabay.com/get/ed6a9369fd0a76647_1920.jpg',
#    'imageURL': 'https://pixabay.com/get/ed6a9364a9fd0a76647.jpg',
#    'imageWidth': 4000,
#    'imageHeight': 2250,
#    'imageSize': 4731420,
#    'views': 7671,
#    'downloads': 6439,
#    'likes': 5,
#    'comments': 2,
#    'user_id': 48777,
#    'user': 'Josch13',
#    'userImageURL': 'https://cdn.pixabay.com/user/2013/11/05/02-10-23-764_250x250.jpg'}]}

# %%
# Results returned from an image search 
import requests


def get_images(search_term):
    url = "https://pixabay.com/api/"

    parameters = {
        "key": PIXABAY_API_KEY,
        "q": search_term,
        "image_type": "photo",
        "per_page": 5
    }

    response = requests.get(url, params=parameters)

    if response.status_code == 200:
        data = response.json()
        images = data["hits"]

        if not images:
            return f"No images were found for '{search_term}'."

        result = f"Found {data['totalHits']} images for '{search_term}':\n\n"

        for image in images:
            result += (
                f"Title/tags: {image['tags']}\n"
                f"Photographer: {image['user']}\n"
                f"Image link: {image['webformatURL']}\n\n"
            )

        return result

    return "I couldn't retrieve the image information."


print(get_images("cars"))
# Out:
# Found 500 images for 'cars':
#
# Title/tags: cars, super cars, luxury cars, lamborghini, corvette, black car, white car, sports cars, exotic cars, daytime, parked cars, car row, black lamborghini, white lamborghini, black corvette, high-end vehicles, automobile, car collection, outdoor
# Photographer: futuremoon
# Image link: https://pixabay.com/get/ge85b7c3fd14d9574a43f4ac5671ff0e9b3ea28fab9fd62feb4ed0c11006e19684b1cf2f9e3d1c8d704a07bc9967ea538a2dc47672497fe3b0b19b29b4b7367f8_640.jpg
#
# Title/tags: car, racing, speed, aston martin, automobile, race car, sports car, car wallpapers, motorsport, racetrack, sports
# Photographer: mibro
# Image link: https://pixabay.com/get/gf84ff852036176066b270dd0ad8001e4cd16335323ba7131290409e60452148abe8f6a19d73292d3e57b99b0ba7344395583e54ffab62b330b806701a95e65ad_640.jpg
#
# ...

# %%
import requests
# Free no API key needed, supports KES and 160+ other currencies: https://open.er-api.com
def convert_currency(amount, from_currency, to_currency):
    url = f"https://open.er-api.com/v6/latest/{from_currency}"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        rate = data["rates"][to_currency]
        converted_amount = amount * rate
        return f"{amount}{from_currency} is equal to {round (converted_amount, 2)} {to_currency}."
    else:
        return "I couldn't retreive the exchange rate information."


print(convert_currency(150, "USD", "KES"))
# Out:
# 150USD is equal to 19415.58 KES.
